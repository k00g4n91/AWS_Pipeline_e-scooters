# %% [markdown]
# ## Flights API

# %%
import requests
import json
import re
from pyowm.owm import OWM
import pandas as pd
import datetime
from IPython.display import JSON

# %%
icao = 'EDDB' #berlin germany
tomorrow = (datetime.datetime.today() + datetime.timedelta(days=1)).isoformat()[:10]
tomorrow
# Out:
# '2022-04-18'

# %% [markdown]
# ### Connect to flights Api

# %%
# code copied from API:
url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{tomorrow}T00:00/{tomorrow}T12:00"
querystring = {"withLeg":"true","withCancelled":"true","withCodeshared":"true","withCargo":"true",
               "withPrivate":"false","withLocation":"false"}
headers = {
    "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com",
    "X-RapidAPI-Key": '542b426faamsh04f22b0d9747b0cp11f2c0jsn8e3a0be981a2'
}
response = requests.request("GET", url, headers=headers, params=querystring)

# %%
response.json()
# Out:
# {'departures': [{'departure': {'scheduledTimeLocal': '2022-04-18 06:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 04:00Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LGRP',
#      'iata': 'RHO',
#      'name': 'Rodes Island'},
#     'scheduledTimeLocal': '2022-04-18 10:15+03:00',
#     'scheduledTimeUtc': '2022-04-18 07:15Z',
#     'quality': ['Basic']},
#    'number': 'FR 351',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 06:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 04:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LPPT', 'iata': 'LIS', 'name': 'Lisbon'},
#     'scheduledTimeLocal': '2022-04-18 08:50+01:00',
#     'actualTimeLocal': '2022-04-18 08:50+01:00',
#     'scheduledTimeUtc': '2022-04-18 07:50Z',
#     'actualTimeUtc': '2022-04-18 07:50Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'TP 531',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'TAP Air Portugal'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 06:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 04:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca'},
#     'scheduledTimeLocal': '2022-04-18 08:45+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:45Z',
#     'quality': ['Basic']},
#    'number': 'U2 4501',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 06:05+02:00',
#     'scheduledTimeUtc': '2022-04-18 04:05Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LLBG',
#      'iata': 'TLV',
#      'name': 'Tel Aviv Yafo'},
#     'scheduledTimeLocal': '2022-04-18 11:05+03:00',
#     'scheduledTimeUtc': '2022-04-18 08:05Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'FR 6472',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 06:10+02:00',
#     'scheduledTimeUtc': '2022-04-18 04:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LPPR', 'iata': 'OPO', 'name': 'Porto'},
#     'scheduledTimeLocal': '2022-04-18 08:35+01:00',
#     'scheduledTimeUtc': '2022-04-18 07:35Z',
#     'quality': ['Basic']},
#    'number': 'U2 4535',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 06:10+02:00',
#     'scheduledTimeUtc': '2022-04-18 04:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse'},
#     'scheduledTimeLocal': '2022-04-18 07:40+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:40Z',
#     'quality': ['Basic']},
#    'number': 'U2 5629',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 06:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 04:15Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'scheduledTimeLocal': '2022-04-18 08:05+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:05Z',
#     'terminal': '2F',
#     'quality': ['Basic']},
#    'number': 'AF 1135',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 06:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 04:15Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EBBR', 'iata': 'BRU', 'name': 'Brussels'},
#     'scheduledTimeLocal': '2022-04-18 07:45+02:00',
#     'actualTimeLocal': '2022-04-18 07:45+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:45Z',
#     'actualTimeUtc': '2022-04-18 05:45Z',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 162',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 06:20+02:00',
#     'scheduledTimeUtc': '2022-04-18 04:20Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LEBL', 'iata': 'BCN', 'name': 'Barcelona'},
#     'scheduledTimeLocal': '2022-04-18 09:00+02:00',
#     'actualTimeLocal': '2022-04-18 09:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:00Z',
#     'actualTimeUtc': '2022-04-18 07:00Z',
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 132',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 06:20+02:00',
#     'scheduledTimeUtc': '2022-04-18 04:20Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LIRF', 'iata': 'FCO', 'name': 'Rome'},
#     'scheduledTimeLocal': '2022-04-18 08:20+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:20Z',
#     'terminal': '3',
#     'quality': ['Basic']},
#    'number': 'FR 134',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 06:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 04:30Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EHAM', 'iata': 'AMS', 'name': 'Amsterdam'},
#     'scheduledTimeLocal': '2022-04-18 08:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:00Z',
#     'quality': ['Basic']},
#    'number': 'U2 4561',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 06:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 04:30Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EGSS', 'iata': 'STN', 'name': 'London'},
#     'scheduledTimeLocal': '2022-04-18 07:20+01:00',
#     'scheduledTimeUtc': '2022-04-18 06:20Z',
#     'quality': ['Basic']},
#    'number': 'FR 144',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 06:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 04:30Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LIME', 'iata': 'BGY', 'name': 'Bergamo'},
#     'scheduledTimeLocal': '2022-04-18 08:10+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:10Z',
#     'quality': ['Basic']},
#    'number': 'FR 4732',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 06:35+02:00',
#     'scheduledTimeUtc': '2022-04-18 04:35Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LEMG', 'iata': 'AGP', 'name': 'Málaga'},
#     'scheduledTimeLocal': '2022-04-18 10:10+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:10Z',
#     'quality': ['Basic']},
#    'number': 'U2 4521',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 06:40+02:00',
#     'scheduledTimeUtc': '2022-04-18 04:40Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'scheduledTimeLocal': '2022-04-18 08:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:15Z',
#     'quality': ['Basic']},
#    'number': 'U2 5861',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 06:45+02:00',
#     'scheduledTimeUtc': '2022-04-18 04:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTimeLocal': '2022-04-18 07:55+02:00',
#     'actualTimeLocal': '2022-04-18 07:55+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:55Z',
#     'actualTimeUtc': '2022-04-18 05:55Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 173',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIRL', 'modeS': '3C664C', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 06:55+02:00',
#     'scheduledTimeUtc': '2022-04-18 04:55Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EBBR', 'iata': 'BRU', 'name': 'Brussels'},
#     'scheduledTimeLocal': '2022-04-18 08:15+02:00',
#     'actualTimeLocal': '2022-04-18 08:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:15Z',
#     'actualTimeUtc': '2022-04-18 06:15Z',
#     'quality': ['Basic', 'Live']},
#    'number': 'SN 2592',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Brussels'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LEMD', 'iata': 'MAD', 'name': 'Madrid'},
#     'scheduledTimeLocal': '2022-04-18 10:10+02:00',
#     'actualTimeLocal': '2022-04-18 10:10+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:10Z',
#     'actualTimeUtc': '2022-04-18 08:10Z',
#     'terminal': '4',
#     'quality': ['Basic', 'Live']},
#    'number': 'IB 3057',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Iberia'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna'},
#     'scheduledTimeLocal': '2022-04-18 08:15+02:00',
#     'actualTimeLocal': '2022-04-18 08:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:15Z',
#     'actualTimeUtc': '2022-04-18 06:15Z',
#     'terminal': '3',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 240',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LLBG',
#      'iata': 'TLV',
#      'name': 'Tel Aviv Yafo'},
#     'scheduledTimeLocal': '2022-04-18 12:15+03:00',
#     'scheduledTimeUtc': '2022-04-18 09:15Z',
#     'terminal': '3',
#     'quality': ['Basic']},
#    'number': 'U2 5201',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#     'scheduledTimeLocal': '2022-04-18 08:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:15Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 5511',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'scheduledTimeLocal': '2022-04-18 08:30+02:00',
#     'actualTimeLocal': '2022-04-18 08:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:30Z',
#     'actualTimeUtc': '2022-04-18 06:30Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 963',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321'},
#    'airline': {'name': 'SWISS'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LTFM', 'iata': 'IST', 'name': 'Istanbul'},
#     'scheduledTimeLocal': '2022-04-18 11:00+03:00',
#     'scheduledTimeUtc': '2022-04-18 08:00Z',
#     'quality': ['Basic']},
#    'number': 'TK 1728',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321'},
#    'airline': {'name': 'Turkish'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'scheduledTimeLocal': '2022-04-18 08:10+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:10Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': 'U2 5681',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:05+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:05Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EGKK', 'iata': 'LGW', 'name': 'London'},
#     'scheduledTimeLocal': '2022-04-18 08:10+01:00',
#     'scheduledTimeUtc': '2022-04-18 07:10Z',
#     'terminal': 'N',
#     'quality': ['Basic']},
#    'number': 'U2 8208',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:05+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:05Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LSGG', 'iata': 'GVA', 'name': 'Geneva'},
#     'scheduledTimeLocal': '2022-04-18 08:50+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:50Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 1590',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:10+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EHAM', 'iata': 'AMS', 'name': 'Amsterdam'},
#     'scheduledTimeLocal': '2022-04-18 08:40+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:40Z',
#     'quality': ['Basic']},
#    'number': 'U2 5101',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:10+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EGLL', 'iata': 'LHR', 'name': 'London'},
#     'scheduledTimeLocal': '2022-04-18 08:15+01:00',
#     'actualTimeLocal': '2022-04-18 08:15+01:00',
#     'scheduledTimeUtc': '2022-04-18 07:15Z',
#     'actualTimeUtc': '2022-04-18 07:15Z',
#     'terminal': '5',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 981',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'British Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:15Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'BKPR', 'iata': 'PRN', 'name': 'Prishtina'},
#     'scheduledTimeLocal': '2022-04-18 09:45+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:45Z',
#     'quality': ['Basic']},
#    'number': 'U2 4579',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:15Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LIMC', 'iata': 'MXP', 'name': 'Milan'},
#     'scheduledTimeLocal': '2022-04-18 09:05+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:05Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 4673',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:15Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca'},
#     'scheduledTimeLocal': '2022-04-18 10:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:00Z',
#     'quality': ['Basic']},
#    'number': 'U2 5801',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:20+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:20Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTimeLocal': '2022-04-18 08:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:30Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': 'LH 1963',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:20+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:20Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LROP', 'iata': 'OTP', 'name': 'Bucharest'},
#     'scheduledTimeLocal': '2022-04-18 10:30+03:00',
#     'scheduledTimeUtc': '2022-04-18 07:30Z',
#     'quality': ['Basic']},
#    'number': 'FR 314',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:25+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:25Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LIRF', 'iata': 'FCO', 'name': 'Rome'},
#     'scheduledTimeLocal': '2022-04-18 09:40+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:40Z',
#     'terminal': '3',
#     'quality': ['Basic']},
#    'number': 'U2 5701',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:30Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'ESSA', 'iata': 'ARN', 'name': 'Stockholm'},
#     'scheduledTimeLocal': '2022-04-18 09:20+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:20Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': 'U2 5211',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:30Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LGTS',
#      'iata': 'SKG',
#      'name': 'Thessaloniki'},
#     'scheduledTimeLocal': '2022-04-18 10:55+03:00',
#     'scheduledTimeUtc': '2022-04-18 07:55Z',
#     'quality': ['Basic']},
#    'number': 'FR 1146',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 07:45+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTimeLocal': '2022-04-18 08:55+02:00',
#     'actualTimeLocal': '2022-04-18 08:55+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:55Z',
#     'actualTimeUtc': '2022-04-18 06:55Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 175',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIUC', 'modeS': '3C66A3', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 08:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LIRF', 'iata': 'FCO', 'name': 'Rome'},
#     'scheduledTimeLocal': '2022-04-18 10:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:15Z',
#     'terminal': '3',
#     'quality': ['Basic']},
#    'number': 'U2 5703',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 08:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LLBG',
#      'iata': 'TLV',
#      'name': 'Tel Aviv Yafo'},
#     'scheduledTimeLocal': '2022-04-18 13:15+03:00',
#     'scheduledTimeUtc': '2022-04-18 10:15Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 5831',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 08:10+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'scheduledTimeLocal': '2022-04-18 09:25+02:00',
#     'actualTimeLocal': '2022-04-18 09:25+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:25Z',
#     'actualTimeUtc': '2022-04-18 07:25Z',
#     'terminal': 'A',
#     'gate': 'A40',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 9049',
#    'callSign': 'GWI9UW',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 08:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:15Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LOWS', 'iata': 'SZG', 'name': 'Salzburg'},
#     'scheduledTimeLocal': '2022-04-18 09:25+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:25Z',
#     'quality': ['Basic']},
#    'number': 'EW 4343',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 08:20+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:20Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTimeLocal': '2022-04-18 09:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:30Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': 'LH 1927',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 08:20+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:20Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LHBP', 'iata': 'BUD', 'name': 'Budapest'},
#     'scheduledTimeLocal': '2022-04-18 09:45+02:00',
#     'actualTimeLocal': '2022-04-18 09:45+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:45Z',
#     'actualTimeUtc': '2022-04-18 07:45Z',
#     'terminal': '2A',
#     'quality': ['Basic', 'Live']},
#    'number': 'W6 2316',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Wizz Air'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 08:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:30Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse'},
#     'scheduledTimeLocal': '2022-04-18 10:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:00Z',
#     'quality': ['Basic']},
#    'number': 'U2 5631',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 08:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:30Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'scheduledTimeLocal': '2022-04-18 10:25+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:25Z',
#     'terminal': '2D',
#     'quality': ['Basic']},
#    'number': 'U2 5673',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 08:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:30Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LRCL',
#      'iata': 'CLJ',
#      'name': 'Cluj-Napoca'},
#     'scheduledTimeLocal': '2022-04-18 11:20+03:00',
#     'scheduledTimeUtc': '2022-04-18 08:20Z',
#     'quality': ['Basic']},
#    'number': 'W6 3358',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Wizz Air'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 08:40+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:40Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LQTZ', 'iata': 'TZL', 'name': 'Tuzla'},
#     'scheduledTimeLocal': '2022-04-18 10:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:30Z',
#     'quality': ['Basic']},
#    'number': 'W6 4276',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Wizz Air'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 08:45+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'ELLX',
#      'iata': 'LUX',
#      'name': 'Luxembourg'},
#     'scheduledTimeLocal': '2022-04-18 10:15+02:00',
#     'actualTimeLocal': '2022-04-18 10:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:15Z',
#     'actualTimeUtc': '2022-04-18 08:15Z',
#     'quality': ['Basic', 'Live']},
#    'number': 'LG 9472',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Bombardier Dash 8 Q400 / DHC-8-400'},
#    'airline': {'name': 'Luxair'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 08:50+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:50Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LDZD', 'iata': 'ZAD', 'name': 'Zadar'},
#     'scheduledTimeLocal': '2022-04-18 10:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:30Z',
#     'quality': ['Basic']},
#    'number': 'FR 2920',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 09:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EVRA', 'iata': 'RIX', 'name': 'Riga'},
#     'scheduledTimeLocal': '2022-04-18 11:35+03:00',
#     'actualTimeLocal': '2022-04-18 11:35+03:00',
#     'scheduledTimeUtc': '2022-04-18 08:35Z',
#     'actualTimeUtc': '2022-04-18 08:35Z',
#     'terminal': 'E',
#     'quality': ['Basic', 'Live']},
#    'number': 'BT 212',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A220-300'},
#    'airline': {'name': 'Air Baltic'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 09:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'HEGN', 'iata': 'HRG', 'name': 'Hurghada'},
#     'scheduledTimeLocal': '2022-04-18 13:35+02:00',
#     'scheduledTimeUtc': '2022-04-18 11:35Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'DE 432',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321'},
#    'airline': {'name': 'Condor'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 09:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna'},
#     'scheduledTimeLocal': '2022-04-18 10:15+02:00',
#     'actualTimeLocal': '2022-04-18 10:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:15Z',
#     'actualTimeUtc': '2022-04-18 08:15Z',
#     'terminal': '3',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 224',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 09:05+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:05Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EHAM', 'iata': 'AMS', 'name': 'Amsterdam'},
#     'scheduledTimeLocal': '2022-04-18 10:40+02:00',
#     'actualTimeLocal': '2022-04-18 10:32+02:00',
#     'runwayTimeLocal': '2022-04-18 10:32+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:40Z',
#     'actualTimeUtc': '2022-04-18 08:32Z',
#     'runwayTimeUtc': '2022-04-18 08:32Z',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1822',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 09:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:15Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EFHK', 'iata': 'HEL', 'name': 'Helsinki'},
#     'scheduledTimeLocal': '2022-04-18 12:05+03:00',
#     'actualTimeLocal': '2022-04-18 12:05+03:00',
#     'scheduledTimeUtc': '2022-04-18 09:05Z',
#     'actualTimeUtc': '2022-04-18 09:05Z',
#     'terminal': '2',
#     'baggageBelt': '22',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 1432',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Finnair'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 09:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:30Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'scheduledTimeLocal': '2022-04-18 11:00+02:00',
#     'actualTimeLocal': '2022-04-18 11:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:00Z',
#     'actualTimeUtc': '2022-04-18 09:00Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 975',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'SWISS'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 09:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:30Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#     'scheduledTimeLocal': '2022-04-18 11:40+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:40Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': 'U2 4545',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 09:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:30Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'WSSS', 'iata': 'SIN', 'name': 'Singapore'},
#     'scheduledTimeLocal': '2022-04-19 04:40+08:00',
#     'scheduledTimeUtc': '2022-04-18 20:40Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'TR 735',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787-8'},
#    'airline': {'name': 'Scoot'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 09:35+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:35Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LRIA', 'iata': 'IAS', 'name': 'Iaşi'},
#     'scheduledTimeLocal': '2022-04-18 12:45+03:00',
#     'scheduledTimeUtc': '2022-04-18 09:45Z',
#     'quality': ['Basic']},
#    'number': 'W6 8720',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Wizz Air'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 09:40+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:40Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca'},
#     'scheduledTimeLocal': '2022-04-18 12:25+02:00',
#     'actualTimeLocal': '2022-04-18 12:25+02:00',
#     'scheduledTimeUtc': '2022-04-18 10:25Z',
#     'actualTimeUtc': '2022-04-18 10:25Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 278',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 09:45+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTimeLocal': '2022-04-18 10:55+02:00',
#     'actualTimeLocal': '2022-04-18 10:55+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:55Z',
#     'actualTimeUtc': '2022-04-18 08:55Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 181',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AISN', 'modeS': '3C666E', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 09:45+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EGGW', 'iata': 'LTN', 'name': 'London'},
#     'scheduledTimeLocal': '2022-04-18 10:40+01:00',
#     'scheduledTimeUtc': '2022-04-18 09:40Z',
#     'quality': ['Basic']},
#    'number': 'U2 2102',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 09:45+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'ENGM', 'iata': 'OSL', 'name': 'Oslo'},
#     'scheduledTimeLocal': '2022-04-18 11:25+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:25Z',
#     'quality': ['Basic']},
#    'number': 'DY 1103',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Norwegian Air Shuttle'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 09:45+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LYBE', 'iata': 'BEG', 'name': 'Belgrade'},
#     'scheduledTimeLocal': '2022-04-18 11:25+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:25Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': 'JU 351',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Air Serbia'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 09:50+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:50Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTimeLocal': '2022-04-18 11:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:00Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': 'LH 1931',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 09:50+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:50Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'KEWR', 'iata': 'EWR', 'name': 'Newark'},
#     'scheduledTimeLocal': '2022-04-18 13:05-04:00',
#     'scheduledTimeUtc': '2022-04-18 17:05Z',
#     'terminal': 'B',
#     'quality': ['Basic']},
#    'number': 'UA 963',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 767-300'},
#    'airline': {'name': 'United'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 09:55+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:55Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'scheduledTimeLocal': '2022-04-18 11:45+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:45Z',
#     'terminal': '2F',
#     'quality': ['Basic']},
#    'number': 'AF 1435',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 10:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LIRN', 'iata': 'NAP', 'name': 'Nápoli'},
#     'scheduledTimeLocal': '2022-04-18 12:20+02:00',
#     'scheduledTimeUtc': '2022-04-18 10:20Z',
#     'quality': ['Basic']},
#    'number': 'U2 4896',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 10:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:15Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LIMC', 'iata': 'MXP', 'name': 'Milan'},
#     'scheduledTimeLocal': '2022-04-18 12:05+02:00',
#     'scheduledTimeUtc': '2022-04-18 10:05Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'FR 8',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 10:20+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:20Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LGTS',
#      'iata': 'SKG',
#      'name': 'Thessaloniki'},
#     'scheduledTimeLocal': '2022-04-18 13:50+03:00',
#     'scheduledTimeUtc': '2022-04-18 10:50Z',
#     'quality': ['Basic']},
#    'number': 'U2 4605',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 10:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:30Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LICC', 'iata': 'CTA', 'name': 'Catania'},
#     'scheduledTimeLocal': '2022-04-18 13:20+02:00',
#     'scheduledTimeUtc': '2022-04-18 11:20Z',
#     'quality': ['Basic']},
#    'number': 'U2 5693',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 10:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:30Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LPPR', 'iata': 'OPO', 'name': 'Porto'},
#     'scheduledTimeLocal': '2022-04-18 12:55+01:00',
#     'scheduledTimeUtc': '2022-04-18 11:55Z',
#     'quality': ['Basic']},
#    'number': 'U2 5811',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 10:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:30Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LEMG', 'iata': 'AGP', 'name': 'Málaga'},
#     'scheduledTimeLocal': '2022-04-18 14:00+02:00',
#     'actualTimeLocal': '2022-04-18 14:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 12:00Z',
#     'actualTimeUtc': '2022-04-18 12:00Z',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 234',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 10:35+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:35Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EHAM', 'iata': 'AMS', 'name': 'Amsterdam'},
#     'scheduledTimeLocal': '2022-04-18 12:05+02:00',
#     'scheduledTimeUtc': '2022-04-18 10:05Z',
#     'quality': ['Basic']},
#    'number': 'U2 4563',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 10:40+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:40Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EIDW', 'iata': 'DUB', 'name': 'Dublin'},
#     'scheduledTimeLocal': '2022-04-18 12:10+01:00',
#     'actualTimeLocal': '2022-04-18 12:10+01:00',
#     'scheduledTimeUtc': '2022-04-18 11:10Z',
#     'actualTimeUtc': '2022-04-18 11:10Z',
#     'terminal': '2',
#     'gate': '307A',
#     'quality': ['Basic', 'Live']},
#    'number': 'EI 333',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Aer Lingus'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 10:40+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:40Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LIBD', 'iata': 'BRI', 'name': 'Bari'},
#     'scheduledTimeLocal': '2022-04-18 12:50+02:00',
#     'scheduledTimeUtc': '2022-04-18 10:50Z',
#     'quality': ['Basic']},
#    'number': 'FR 4085',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 10:45+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTimeLocal': '2022-04-18 11:55+02:00',
#     'actualTimeLocal': '2022-04-18 11:55+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:55Z',
#     'actualTimeUtc': '2022-04-18 09:55Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 183',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 10:50+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:50Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca'},
#     'scheduledTimeLocal': '2022-04-18 13:35+02:00',
#     'scheduledTimeUtc': '2022-04-18 11:35Z',
#     'quality': ['Basic']},
#    'number': 'U2 5805',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 10:50+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:50Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LTAI', 'iata': 'AYT', 'name': 'Antalya'},
#     'scheduledTimeLocal': '2022-04-18 15:10+03:00',
#     'scheduledTimeUtc': '2022-04-18 12:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'XQ 665',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'SunExpress'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 10:50+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:50Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTimeLocal': '2022-04-18 12:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 10:00Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': 'LH 1935',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 10:50+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:50Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'scheduledTimeLocal': '2022-04-18 12:20+02:00',
#     'actualTimeLocal': '2022-04-18 12:20+02:00',
#     'scheduledTimeUtc': '2022-04-18 10:20Z',
#     'actualTimeUtc': '2022-04-18 10:20Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 977',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321'},
#    'airline': {'name': 'SWISS'}},
#   {'departure': {'scheduledTimeLocal': '2022-04-18 10:55+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:55Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EGLL', 'iata': 'LHR', 'name': 'London'},
#     'scheduledTimeLocal': '2022-04-18 12:00+01:00',
#     'actualTimeLocal': '2022-04-18 12:00+01:00',
#     'scheduledTimeUtc': '2022-04-18 11:00Z',
#     'actualTimeUtc': '2022-04-18 11:00Z',
#     'terminal': '5',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 991',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'British Airways'}},
# ...
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'scheduledTimeLocal': '2022-04-18 08:45+02:00',
#     'actualTimeLocal': '2022-04-18 08:45+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:45Z',
#     'actualTimeUtc': '2022-04-18 06:45Z',
#     'checkInDesk': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 10:05+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:05Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'LX 976',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321'},
#    'airline': {'name': 'SWISS'}},
#   {'departure': {'airport': {'icao': 'LTBJ', 'iata': 'ADB', 'name': 'İzmir'},
#     'scheduledTimeLocal': '2022-04-18 08:00+03:00',
#     'scheduledTimeUtc': '2022-04-18 05:00Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 10:05+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:05Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'number': 'XC 3511',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Corendon Air'}},
#   {'departure': {'airport': {'icao': 'LIME', 'iata': 'BGY', 'name': 'Bergamo'},
#     'scheduledTimeLocal': '2022-04-18 08:35+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:35Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 10:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:15Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'number': 'FR 4731',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'airport': {'name': 'Zurich'}, 'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 10:20+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:20Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 5862',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna'},
#     'scheduledTimeLocal': '2022-04-18 09:15+02:00',
#     'actualTimeLocal': '2022-04-18 09:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:15Z',
#     'actualTimeUtc': '2022-04-18 07:15Z',
#     'terminal': '3',
#     'checkInDesk': '351-368',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 10:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:30Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'OS 225',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam'},
#     'scheduledTimeLocal': '2022-04-18 09:10+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:10Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 10:35+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:35Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 5102',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'airport': {'icao': 'EGSS', 'iata': 'STN', 'name': 'London'},
#     'scheduledTimeLocal': '2022-04-18 07:55+01:00',
#     'scheduledTimeUtc': '2022-04-18 06:55Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 10:40+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:40Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'number': 'FR 145',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'airport': {'icao': 'EIDW', 'iata': 'DUB', 'name': 'Dublin'},
#     'scheduledTimeLocal': '2022-04-18 07:20+01:00',
#     'actualTimeLocal': '2022-04-18 07:20+01:00',
#     'scheduledTimeUtc': '2022-04-18 06:20Z',
#     'actualTimeUtc': '2022-04-18 06:20Z',
#     'terminal': '1',
#     'checkInDesk': '1204-1319',
#     'gate': '110',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 10:40+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:40Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'number': 'FR 8556',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'airport': {'icao': 'LPPT', 'iata': 'LIS', 'name': 'Lisbon'},
#     'scheduledTimeLocal': '2022-04-18 06:10+01:00',
#     'scheduledTimeUtc': '2022-04-18 05:10Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 10:50+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:50Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 7651',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'airport': {'icao': 'EBBR',
#      'iata': 'BRU',
#      'name': 'Brussels'},
#     'scheduledTimeLocal': '2022-04-18 09:25+02:00',
#     'actualTimeLocal': '2022-04-18 09:25+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:25Z',
#     'actualTimeUtc': '2022-04-18 07:25Z',
#     'checkInDesk': '04',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 10:50+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:50Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'SN 2581',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'Brussels'}},
#   {'departure': {'airport': {'icao': 'LEMD', 'iata': 'MAD', 'name': 'Madrid'},
#     'scheduledTimeLocal': '2022-04-18 07:50+02:00',
#     'actualTimeLocal': '2022-04-18 07:50+02:00',
#     'scheduledTimeUtc': '2022-04-18 05:50Z',
#     'actualTimeUtc': '2022-04-18 05:50Z',
#     'terminal': '4',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 10:55+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:55Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'IB 3066',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Iberia'}},
#   {'departure': {'airport': {'icao': 'LIRF', 'iata': 'FCO', 'name': 'Rome'},
#     'scheduledTimeLocal': '2022-04-18 08:55+02:00',
#     'scheduledTimeUtc': '2022-04-18 06:55Z',
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 11:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:00Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'number': 'FR 135',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'airport': {'name': 'London'}, 'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 11:05+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:05Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'BA 8491',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'British Airways'}},
#   {'departure': {'airport': {'icao': 'EPWA', 'iata': 'WAW', 'name': 'Warsaw'},
#     'scheduledTimeLocal': '2022-04-18 09:50+02:00',
#     'actualTimeLocal': '2022-04-18 09:50+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:50Z',
#     'actualTimeUtc': '2022-04-18 07:50Z',
#     'terminal': 'E-D',
#     'checkInDesk': '241-280',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 11:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:15Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'LO 387',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Bombardier Dash 8 Q400 / DHC-8-400'},
#    'airline': {'name': 'LOT - Polish'}},
#   {'departure': {'airport': {'icao': 'LSGG', 'iata': 'GVA', 'name': 'Geneva'},
#     'scheduledTimeLocal': '2022-04-18 09:30+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:30Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 11:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:15Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 1591',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'scheduledTimeLocal': '2022-04-18 09:35+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:35Z',
#     'terminal': '2F',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 11:20+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:20Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'AF 1734',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'airport': {'icao': 'LTFJ',
#      'iata': 'SAW',
#      'name': 'Istanbul'},
#     'scheduledTimeLocal': '2022-04-18 09:25+03:00',
#     'scheduledTimeUtc': '2022-04-18 06:25Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 11:20+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:20Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'TK 7728',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Turkish'}},
#   {'departure': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm'},
#     'scheduledTimeLocal': '2022-04-18 09:55+02:00',
#     'actualTimeLocal': '2022-04-18 09:55+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:55Z',
#     'actualTimeUtc': '2022-04-18 07:55Z',
#     'terminal': '5',
#     'checkInDesk': '52-55',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 11:25+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:25Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'SK 2677',
#    'callSign': 'SAS2677',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-FPV',
#     'modeS': '4CACCA',
#     'model': 'Bombardier CRJ900'},
#    'airline': {'name': 'SAS'}},
#   {'departure': {'airport': {'icao': 'LIMC', 'iata': 'MXP', 'name': 'Milan'},
#     'scheduledTimeLocal': '2022-04-18 09:35+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:35Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 11:25+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:25Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 4672',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'airport': {'icao': 'LTAI', 'iata': 'AYT', 'name': 'Antalya'},
#     'scheduledTimeLocal': '2022-04-18 09:00+03:00',
#     'scheduledTimeUtc': '2022-04-18 06:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 11:35+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:35Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'XQ 160',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'SunExpress'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart'},
#     'scheduledTimeLocal': '2022-04-18 10:20+02:00',
#     'actualTimeLocal': '2022-04-18 10:20+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:20Z',
#     'actualTimeUtc': '2022-04-18 08:20Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 11:35+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:35Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'EW 2010',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings'}},
#   {'departure': {'airport': {'name': 'Stockholm'}, 'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 11:40+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:40Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 5212',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'airport': {'name': 'London'}, 'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 11:40+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:40Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'BA 982',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'British Airways'}},
#   {'departure': {'airport': {'icao': 'BIKF',
#      'iata': 'KEF',
#      'name': 'Reykjavik'},
#     'scheduledTimeLocal': '2022-04-18 06:00+00:00',
#     'actualTimeLocal': '2022-04-18 06:00+00:00',
#     'scheduledTimeUtc': '2022-04-18 06:00Z',
#     'actualTimeUtc': '2022-04-18 06:00Z',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 11:40+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:40Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'OG 700',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Ghodawat Enterprises'}},
#   {'departure': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm'},
#     'scheduledTimeLocal': '2022-04-18 10:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 08:00Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 11:45+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 5882',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'airport': {'icao': 'EGKK', 'iata': 'LGW', 'name': 'London'},
#     'scheduledTimeLocal': '2022-04-18 08:45+01:00',
#     'scheduledTimeUtc': '2022-04-18 07:45Z',
#     'terminal': 'N',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 11:45+02:00',
#     'scheduledTimeUtc': '2022-04-18 09:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 8209',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca'},
#     'scheduledTimeLocal': '2022-04-18 09:15+02:00',
#     'actualTimeLocal': '2022-04-18 09:15+02:00',
#     'scheduledTimeUtc': '2022-04-18 07:15Z',
#     'actualTimeUtc': '2022-04-18 07:15Z',
#     'terminal': 'N',
#     'checkInDesk': '002-017',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-04-18 12:00+02:00',
#     'scheduledTimeUtc': '2022-04-18 10:00Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'number': 'FR 2146',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}}]}

# %% [markdown]
# ### Unpack this horrendous list of lists of dictionaries

# %%
# Step 1: make a dataframe from all of the information in the json
arrivals = pd.json_normalize(response.json()['arrivals'])

# Step2: select only the columns you want to incude on your database
json_norm_df = pd.DataFrame(arrivals
    .filter(['departure.airport.name','arrival.scheduledTimeLocal',
             'arrival.terminal','status','aircraft.model','number'])
    .assign(icao_code = icao))

json_norm_df
# Out:
#    departure.airport.name arrival.scheduledTimeLocal arrival.terminal  \
# 0             Duesseldorf     2022-04-18 07:35+02:00                1
# 1                  Munich     2022-04-18 07:35+02:00                1
# 2                Salzburg     2022-04-18 07:40+02:00                1
# 3                Budapest     2022-04-18 07:45+02:00                0
# 4                  Newark     2022-04-18 07:50+02:00                1
# ..                    ...                        ...              ...
# 62                 London     2022-04-18 11:40+02:00                1
# 63              Reykjavik     2022-04-18 11:40+02:00                1
# 64              Stockholm     2022-04-18 11:45+02:00                1
# 65                 London     2022-04-18 11:45+02:00                1
# 66      Palma De Mallorca     2022-04-18 12:00+02:00                0
#
#      status   aircraft.model   number icao_code
# 0   Unknown      Airbus A319  EW 9048      EDDB
# 1   Unknown      Airbus A319  LH 1926      EDDB
# 2   Unknown      Airbus A319  EW 4342      EDDB
# 3   Unknown      Airbus A320  W6 2315      EDDB
# 4   Unknown   Boeing 767-300   UA 962      EDDB
# ..      ...              ...      ...       ...
# 62  Unknown      Airbus A319   BA 982      EDDB
# 63  Unknown  Airbus A320 NEO   OG 700      EDDB
# 64  Unknown      Airbus A320  U2 5882      EDDB
# 65  Unknown      Airbus A319  U2 8209      EDDB
# 66  Unknown   Boeing 737-800  FR 2146      EDDB
#
# [67 rows x 7 columns]

# %%
json_norm_df['arrival.scheduledTimeLocal'] = pd.to_datetime(json_norm_df['arrival.scheduledTimeLocal'])
json_norm_df.dtypes
# Out:
# departure.airport.name                                       object
# arrival.scheduledTimeLocal    datetime64[ns, pytz.FixedOffset(120)]
# arrival.terminal                                             object
# status                                                       object
# aircraft.model                                               object
# number                                                       object
# icao_code                                                    object
# dtype: object

# %%
json_norm_df.rename(columns={'departure.airport.name':'departing_from',
                             'arrival.scheduledTimeLocal':'arrival_time_local',
                             'arrival.terminal':'terminal',
                             'aircraft.model':'aircraft_model',
                            'number':'flight_number'}, inplace=True)

json_norm_df['arrival_time_local'] = pd.to_datetime(json_norm_df['arrival_time_local'])
arrivals = json_norm_df
arrivals.head()
# Out:
#   departing_from        arrival_time_local terminal   status  aircraft_model  \
# 0    Duesseldorf 2022-04-18 07:35:00+02:00        1  Unknown     Airbus A319
# 1         Munich 2022-04-18 07:35:00+02:00        1  Unknown     Airbus A319
# 2       Salzburg 2022-04-18 07:40:00+02:00        1  Unknown     Airbus A319
# 3       Budapest 2022-04-18 07:45:00+02:00        0  Unknown     Airbus A320
# 4         Newark 2022-04-18 07:50:00+02:00        1  Unknown  Boeing 767-300
#
#   flight_number icao_code
# 0       EW 9048      EDDB
# 1       LH 1926      EDDB
# 2       EW 4342      EDDB
# 3       W6 2315      EDDB
# 4        UA 962      EDDB

# %% [markdown]
# ### Connecting to OWM Weather API

# %%
import requests

OWM_key = 'b556bcb3a0753fe0399a44800d14a3c2'
city = "Berlin"
country = "DE"
response = requests.get(f'http://api.openweathermap.org/data/2.5/forecast/?q={city},{country}&appid={OWM_key}&units=metric&lang=en')
response
# Out:
# <Response [200]>

# %%
forecast_api = response.json()['list']

weather_info = []

# datetime, temperature, wind, prob_pers, rain_qty, snow = [], [], [], [], [], []
for forecast_3h in forecast_api: 
    weather_hour = {}
    # datetime utc
    weather_hour['datetime'] = forecast_3h['dt_txt']
    # temperature 
    weather_hour['temperature'] = forecast_3h['main']['temp']
    # wind
    weather_hour['wind'] = forecast_3h['wind']['speed']
    # probability precipitation 
    try: weather_hour['prob_perc'] = float(forecast_3h['pop'])
    except: weather_hour['prob_perc'] = 0
    # rain
    try: weather_hour['rain_qty'] = float(forecast_3h['rain']['3h'])
    except: weather_hour['rain_qty'] = 0
    # wind 
    try: weather_hour['snow'] = float(forecast_3h['snow']['3h'])
    except: weather_hour['snow'] = 0
    weather_hour['municipality_iso_country'] = city + ',' + country
    weather_info.append(weather_hour)
    
weather_data = pd.DataFrame(weather_info)
weather_data.head()
# Out:
#               datetime  temperature  wind  prob_perc  rain_qty  snow  \
# 0  2022-04-17 15:00:00        15.34  3.19        0.0       0.0     0
# 1  2022-04-17 18:00:00        13.81  3.34        0.0       0.0     0
# 2  2022-04-17 21:00:00         9.89  3.18        0.0       0.0     0
# 3  2022-04-18 00:00:00         5.52  2.31        0.0       0.0     0
# 4  2022-04-18 03:00:00         4.34  2.07        0.0       0.0     0
#
#   municipality_iso_country
# 0                Berlin,DE
# 1                Berlin,DE
# 2                Berlin,DE
# 3                Berlin,DE
# 4                Berlin,DE

# %%
weather_info
# Out:
# [{'datetime': '2022-04-17 15:00:00',
#   'temperature': 15.34,
#   'wind': 3.19,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-17 18:00:00',
#   'temperature': 13.81,
#   'wind': 3.34,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-17 21:00:00',
#   'temperature': 9.89,
#   'wind': 3.18,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-18 00:00:00',
#   'temperature': 5.52,
#   'wind': 2.31,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-18 03:00:00',
#   'temperature': 4.34,
#   'wind': 2.07,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-18 06:00:00',
#   'temperature': 5.96,
#   'wind': 2.82,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-18 09:00:00',
#   'temperature': 10.49,
#   'wind': 2.77,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-18 12:00:00',
#   'temperature': 13.31,
#   'wind': 2.49,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-18 15:00:00',
#   'temperature': 13.94,
#   'wind': 2.82,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-18 18:00:00',
#   'temperature': 10.61,
#   'wind': 3,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-18 21:00:00',
#   'temperature': 7.86,
#   'wind': 3.08,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-19 00:00:00',
#   'temperature': 7.04,
#   'wind': 2.37,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-19 03:00:00',
#   'temperature': 6.13,
#   'wind': 2.97,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-19 06:00:00',
#   'temperature': 6.58,
#   'wind': 2.97,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-19 09:00:00',
#   'temperature': 10.51,
#   'wind': 4.19,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-19 12:00:00',
#   'temperature': 12.65,
#   'wind': 5.06,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-19 15:00:00',
#   'temperature': 10.37,
#   'wind': 5.98,
#   'prob_perc': 0.28,
#   'rain_qty': 0.16,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-19 18:00:00',
#   'temperature': 7.76,
#   'wind': 3.7,
#   'prob_perc': 0.51,
#   'rain_qty': 0.54,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-19 21:00:00',
#   'temperature': 5.26,
#   'wind': 3.03,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-20 00:00:00',
#   'temperature': 4.61,
#   'wind': 2.1,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-20 03:00:00',
#   'temperature': 3.56,
#   'wind': 2.14,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-20 06:00:00',
#   'temperature': 5.04,
#   'wind': 1.89,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-20 09:00:00',
#   'temperature': 9.6,
#   'wind': 2.32,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-20 12:00:00',
#   'temperature': 12.82,
#   'wind': 2.06,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-20 15:00:00',
#   'temperature': 13.17,
#   'wind': 2.83,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-20 18:00:00',
#   'temperature': 9.24,
#   'wind': 4.64,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-20 21:00:00',
#   'temperature': 6.6,
#   'wind': 3.13,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-21 00:00:00',
#   'temperature': 7.23,
#   'wind': 2.93,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-21 03:00:00',
#   'temperature': 5.98,
#   'wind': 3.14,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-21 06:00:00',
#   'temperature': 6.3,
#   'wind': 3.58,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-21 09:00:00',
#   'temperature': 8.63,
#   'wind': 3.69,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-21 12:00:00',
#   'temperature': 13.42,
#   'wind': 3.16,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-21 15:00:00',
#   'temperature': 14.13,
#   'wind': 3.61,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-21 18:00:00',
#   'temperature': 11.58,
#   'wind': 4.43,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-21 21:00:00',
#   'temperature': 8.36,
#   'wind': 4.21,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-22 00:00:00',
#   'temperature': 8.76,
#   'wind': 3.48,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-22 03:00:00',
#   'temperature': 8.34,
#   'wind': 4.18,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-22 06:00:00',
#   'temperature': 8.54,
#   'wind': 4.55,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-22 09:00:00',
#   'temperature': 8.99,
#   'wind': 4.62,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'},
#  {'datetime': '2022-04-22 12:00:00',
#   'temperature': 9.57,
#   'wind': 5.33,
#   'prob_perc': 0.0,
#   'rain_qty': 0,
#   'snow': 0,
#   'municipality_iso_country': 'Berlin,DE'}]

# %% [markdown]
# ## Population data

# %% [markdown]
# ## Airports data

# %%
import pandas as pd

airports_cities = (
pd.read_csv('airports.csv')
    .query('type == "large_airport"')
    .filter(['name','iso_country','municipality','gps_code'])
    .rename(columns={'gps_code':'icao_code'})
    .assign(municipality_iso_country = lambda x: x['municipality'] + ',' + x['iso_country'])
)
airports_cities.head(1)
# Out:
#                                 name iso_country municipality icao_code  \
# 10890  Honiara International Airport          SB      Honiara      AGGH
#
#       municipality_iso_country
# 10890               Honiara,SB

# %%
(
airports_cities
    .merge(arrivals, on='icao_code', how='inner')
    .merge(weather_data, on='municipality_iso_country', how='inner')
    .head()
)
# Out:
#                          name iso_country municipality icao_code  \
# 0  Berlin Brandenburg Airport          DE       Berlin      EDDB
# 1  Berlin Brandenburg Airport          DE       Berlin      EDDB
# 2  Berlin Brandenburg Airport          DE       Berlin      EDDB
# 3  Berlin Brandenburg Airport          DE       Berlin      EDDB
# 4  Berlin Brandenburg Airport          DE       Berlin      EDDB
#
#   municipality_iso_country departing_from        arrival_time_local terminal  \
# 0                Berlin,DE    Duesseldorf 2022-04-18 07:35:00+02:00        1
# 1                Berlin,DE    Duesseldorf 2022-04-18 07:35:00+02:00        1
# 2                Berlin,DE    Duesseldorf 2022-04-18 07:35:00+02:00        1
# 3                Berlin,DE    Duesseldorf 2022-04-18 07:35:00+02:00        1
# 4                Berlin,DE    Duesseldorf 2022-04-18 07:35:00+02:00        1
#
#     status aircraft_model flight_number             datetime  temperature  \
# 0  Unknown    Airbus A319       EW 9048  2022-04-17 15:00:00        15.34
# 1  Unknown    Airbus A319       EW 9048  2022-04-17 18:00:00        13.81
# 2  Unknown    Airbus A319       EW 9048  2022-04-17 21:00:00         9.89
# 3  Unknown    Airbus A319       EW 9048  2022-04-18 00:00:00         5.52
# 4  Unknown    Airbus A319       EW 9048  2022-04-18 03:00:00         4.34
#
#    wind  prob_perc  rain_qty  snow
# 0  3.19        0.0       0.0     0
# 1  3.34        0.0       0.0     0
# 2  3.18        0.0       0.0     0
# 3  2.31        0.0       0.0     0
# 4  2.07        0.0       0.0     0

# %% [markdown]
# ## Update data into MySQL database

# %% [markdown]
# ### `sqlalchemy`

# %% [markdown]
# #### Establish the connection

# %%
#%pip install sqlalchemy
#%pip install PyMySQL

# %%
import pandas as pd
import sqlalchemy

# %%
schema="gans"
host="127.0.0.1"
user="root"
# change the password to the root password of your MySQLWorkbench
# (you set this up when you set up MySQL)
password="e^J94QDBUpLjLd1z^2X4XJ"
port=3306
con = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %% [markdown]
# #### Update the tables

# %%
(
airports_cities
    .dropna()
    .drop_duplicates()
    .to_sql('airports_cities', if_exists='append', con=con, index=False)
)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# G:\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1750                 if not evt_handled:
# -> 1751                     self.dialect.do_executemany(
#    1752                         cursor, statement, parameters, context
#
# G:\Anaconda\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     196     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 197         rowcount = cursor.executemany(statement, parameters)
#     198         if context is not None:
#
# G:\Anaconda\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     172             assert q_values[0] == "(" and q_values[-1] == ")"
# --> 173             return self._do_execute_many(
#     174                 q_prefix,
#
# G:\Anaconda\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     210             sql += v
# --> 211         rows += self.execute(sql + postfix)
#     212         self.rowcount = rows
#
# G:\Anaconda\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# G:\Anaconda\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#
# G:\Anaconda\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#
# G:\Anaconda\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#
# G:\Anaconda\lib\site-packages\pymysql\connections.py in read(self)
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#
# G:\Anaconda\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#
# G:\Anaconda\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#
# G:\Anaconda\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry 'London,GB' for key 'airports_cities.PRIMARY'")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1832/1526365164.py in <module>
#       1 (
# ----> 2 airports_cities
#       3     .dropna()
#       4     .drop_duplicates()
#       5     .to_sql('airports_cities', if_exists='append', con=con, index=False)
#
# G:\Anaconda\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# G:\Anaconda\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# G:\Anaconda\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1759         )
#    1760
# -> 1761         sql_engine.insert_records(
#    1762             table=table,
#    1763             con=self.connectable,
#
# G:\Anaconda\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# G:\Anaconda\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# G:\Anaconda\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# G:\Anaconda\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# G:\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1261             )
#    1262         else:
# -> 1263             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1264
#    1265     def _execute_function(self, func, multiparams, params, execution_options):
#
# G:\Anaconda\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     321     ):
#     322         if _force or self.supports_execution:
# --> 323             return connection._execute_clauseelement(
#     324                 self, multiparams, params, execution_options
#     325             )
#
# G:\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1450             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1451         )
# -> 1452         ret = self._execute_context(
#    1453             dialect,
#    1454             dialect.execution_ctx_cls._init_compiled,
#
# G:\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1812
#    1813         except BaseException as e:
# -> 1814             self._handle_dbapi_exception(
#    1815                 e, statement, parameters, cursor, context
#    1816             )
#
# G:\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1993                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1994             elif should_wrap:
# -> 1995                 util.raise_(
#    1996                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1997                 )
#
# G:\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# G:\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1749                             break
#    1750                 if not evt_handled:
# -> 1751                     self.dialect.do_executemany(
#    1752                         cursor, statement, parameters, context
#    1753                     )
#
# G:\Anaconda\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     195
#     196     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 197         rowcount = cursor.executemany(statement, parameters)
#     198         if context is not None:
#     199             context._rowcount = rowcount
#
# G:\Anaconda\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     171             q_postfix = m.group(3) or ""
#     172             assert q_values[0] == "(" and q_values[-1] == ")"
# --> 173             return self._do_execute_many(
#     174                 q_prefix,
#     175                 q_values,
#
# G:\Anaconda\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     209                 sql += b","
#     210             sql += v
# --> 211         rows += self.execute(sql + postfix)
#     212         self.rowcount = rows
#     213         return rows
#
# G:\Anaconda\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# G:\Anaconda\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# G:\Anaconda\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# G:\Anaconda\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# G:\Anaconda\lib\site-packages\pymysql\connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# G:\Anaconda\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# G:\Anaconda\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# G:\Anaconda\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'London,GB' for key 'airports_cities.PRIMARY'")
# [SQL: INSERT INTO airports_cities (name, iso_country, municipality, icao_code, municipality_iso_country) VALUES (%(name)s, %(iso_country)s, %(municipality)s, %(icao_code)s, %(municipality_iso_country)s)]
# [parameters: ({'name': 'Honiara International Airport', 'iso_country': 'SB', 'municipality': 'Honiara', 'icao_code': 'AGGH', 'municipality_iso_country': 'Honiara,SB'}, {'name': 'Port Moresby Jacksons International Airport', 'iso_country': 'PG', 'municipality': 'Port Moresby', 'icao_code': 'AYPY', 'municipality_iso_country': 'Port Moresby,PG'}, {'name': 'Keflavik International Airport', 'iso_country': 'IS', 'municipality': 'Reykjavík', 'icao_code': 'BIKF', 'municipality_iso_country': 'Reykjavík,IS'}, {'name': 'Priština Adem Jashari International Airport', 'iso_country': 'XK', 'municipality': 'Prishtina', 'icao_code': 'BKPR', 'municipality_iso_country': 'Prishtina,XK'}, {'name': 'Nanaimo International Air And Space Port / RCAF Nanaimo Base', 'iso_country': 'CA', 'municipality': 'Nanaimo', 'icao_code': 'CYCD', 'municipality_iso_country': 'Nanaimo,CA'}, {'name': 'Edmonton International Airport', 'iso_country': 'CA', 'municipality': 'Edmonton', 'icao_code': 'CYEG', 'municipality_iso_country': 'Edmonton,CA'}, {'name': 'Halifax / Stanfield International Airport', 'iso_country': 'CA', 'municipality': 'Halifax', 'icao_code': 'CYHZ', 'municipality_iso_country': 'Halifax,CA'}, {'name': 'Kelowna International Airport', 'iso_country': 'CA', 'municipality': 'Kelowna', 'icao_code': 'CYLW', 'municipality_iso_country': 'Kelowna,CA'}  ... displaying 10 of 613 total bound parameter sets ...  {'name': 'Dalian Zhoushuizi International Airport', 'iso_country': 'CN', 'municipality': 'Ganjingzi, Dalian', 'icao_code': 'ZYTL', 'municipality_iso_country': 'Ganjingzi, Dalian,CN'}, {'name': 'Shenyang Taoxian International Airport', 'iso_country': 'CN', 'municipality': 'Hunnan, Shenyang', 'icao_code': 'ZYTX', 'municipality_iso_country': 'Hunnan, Shenyang,CN'})]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
(
weather_data
    .assign(datetime = lambda x: pd.to_datetime(x['datetime']))
    .to_sql('weather', if_exists='append', con=con, index=False)
)

# %%
import numpy as np
(
arrivals
    .replace({np.nan},'unknown')
    .assign(arrival_time_local = lambda x: pd.to_datetime(x['arrival_time_local']),
           municipality_iso_country = 'Berlin,DE')
    .to_sql('arrivals', if_exists='append', con=con, index=False)
)

# %%
weather_data.head()
# Out:
#               datetime  temperature  wind  prob_perc  rain_qty  snow  \
# 0  2022-04-17 15:00:00        15.34  3.19        0.0       0.0     0
# 1  2022-04-17 18:00:00        13.81  3.34        0.0       0.0     0
# 2  2022-04-17 21:00:00         9.89  3.18        0.0       0.0     0
# 3  2022-04-18 00:00:00         5.52  2.31        0.0       0.0     0
# 4  2022-04-18 03:00:00         4.34  2.07        0.0       0.0     0
#
#   municipality_iso_country
# 0                Berlin,DE
# 1                Berlin,DE
# 2                Berlin,DE
# 3                Berlin,DE
# 4                Berlin,DE

# %%
arrivals.head()
# Out:
#   departing_from        arrival_time_local terminal   status  aircraft_model  \
# 0    Duesseldorf 2022-04-18 07:35:00+02:00        1  Unknown     Airbus A319
# 1         Munich 2022-04-18 07:35:00+02:00        1  Unknown     Airbus A319
# 2       Salzburg 2022-04-18 07:40:00+02:00        1  Unknown     Airbus A319
# 3       Budapest 2022-04-18 07:45:00+02:00        0  Unknown     Airbus A320
# 4         Newark 2022-04-18 07:50:00+02:00        1  Unknown  Boeing 767-300
#
#   flight_number icao_code
# 0       EW 9048      EDDB
# 1       LH 1926      EDDB
# 2       EW 4342      EDDB
# 3       W6 2315      EDDB
# 4        UA 962      EDDB

# %%
airports_cities.sample(100)
# Out:
#                                                     name iso_country  \
# 36288                               McGhee Tyson Airport          US
# 23096               Kenneth Kaunda International Airport          ZM
# 64351                 Rajiv Gandhi International Airport          IN
# 57271                            Khabarovsk Novy Airport          RU
# 25636                      Roberts International Airport          LR
# ...                                                  ...         ...
# 39472                Norman Manley International Airport          JM
# 47417                        Gimpo International Airport          KR
# 34223  Louis Armstrong New Orleans International Airport          US
# 68177            Shanghai Hongqiao International Airport          CN
# 57105                                  Sary-Arka Airport          KZ
#
#              municipality icao_code municipality_iso_country
# 36288           Knoxville      KTYS             Knoxville,US
# 23096              Lusaka      FLKK                Lusaka,ZM
# 64351           Hyderabad      VOHS             Hyderabad,IN
# 57271          Khabarovsk      UHHH            Khabarovsk,RU
# 25636            Monrovia      GLRB              Monrovia,LR
# ...                   ...       ...                      ...
# 39472            Kingston      MKJP              Kingston,JM
# 47417               Seoul      RKSS                 Seoul,KR
# 34223         New Orleans      KMSY           New Orleans,US
# 68177  Shanghai (Minhang)      ZSSS    Shanghai (Minhang),CN
# 57105           Karaganda      UAKK             Karaganda,KZ
#
# [100 rows x 5 columns]
